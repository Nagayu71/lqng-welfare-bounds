# %%
import time
import pickle
import networkx as nx
from utils import sample_chunglu_spectra

# %%
# load network data
with open("data/graph_adj_csr.pkl", "rb") as f:
    data = pickle.load(f)

# adjacency matrices (scipy.sparse._csr.csr_matrix)
karate = data["Karate"]
student = data["Student"]
jazz = data["Jazz"]
facebook = data["FB"]
FB1 = data["FB1"]
netsci = data["NetSci"]

# %%
start = time.time()
sample_chunglu_spectra(nx.from_scipy_sparse_array(karate), outfile="data/Karate_spectra.npz")
end = time.time()
print(f"Time taken to compute spectra: {end - start:.2f} seconds")
# Out:
# Time taken to compute spectra: 5.87 seconds

# %%
start = time.time()
sample_chunglu_spectra(nx.from_scipy_sparse_array(student), outfile="data/Student_spectra.npz")
end = time.time()
print(f"Time taken to compute spectra: {end - start:.2f} seconds")
# Out:
# Time taken to compute spectra: 28.94 seconds

# %%
start = time.time()
sample_chunglu_spectra(nx.from_scipy_sparse_array(jazz), outfile="data/Jazz_spectra.npz")
end = time.time()
print(f"Time taken to compute spectra: {end - start:.2f} seconds")
# Out:
# Time taken to compute spectra: 140.05 seconds

# %%
start = time.time()
sample_chunglu_spectra(nx.from_scipy_sparse_array(facebook), outfile="data/FB_spectra.npz")
end = time.time()
print(f"Time taken to compute spectra: {end - start:.2f} seconds")
# Out:
# Time taken to compute spectra: 212.36 seconds

# %%
start = time.time()
sample_chunglu_spectra(nx.from_scipy_sparse_array(FB1), outfile="data/FB1_spectra.npz")
end = time.time()
print(f"Time taken to compute spectra: {end - start:.2f} seconds")
# Out:
# Time taken to compute spectra: 221.53 seconds

# %%
start = time.time()
sample_chunglu_spectra(nx.from_scipy_sparse_array(netsci), outfile="data/NetSci_spectra.npz")
end = time.time()
print(f"Time taken to compute spectra: {end - start:.2f} seconds")
# Out:
# Time taken to compute spectra: 216.40 seconds
