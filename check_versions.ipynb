# %%
import time
import json
import pickle
import matplotlib
import numpy as np
import pandas as pd
import networkx as nx
import graph_tool.all as gt
from datetime import datetime
from typing import Tuple
import sys

print("Package versions:")
print(f"Python:     {sys.version}")
print(f"NumPy:      {np.__version__}")
print(f"Pandas:     {pd.__version__}")
print(f"Matplotlib:  {matplotlib.__version__}")
print(f"NetworkX:   {nx.__version__}")
print(f"Graph-tool:  {gt.__version__}")

print("Standard libraries (time, json, pickle, datetime, typing): built-in modules")
# Out:
# Package versions:
# Python:     3.13.2 | packaged by conda-forge | (main, Feb 17 2025, 14:02:48) [Clang 18.1.8 ]
# NumPy:      2.1.3
# Pandas:     2.2.3
# Matplotlib:  3.10.1
# NetworkX:   3.4.2
# Graph-tool:  2.92 (commit , )
# Standard libraries (time, json, pickle, datetime, typing): built-in modules
